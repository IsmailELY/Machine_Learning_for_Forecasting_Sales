# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.offline as pyo
import numpy as np
import os
from tqdm.notebook import tqdm
import cufflinks as cf               # third-party library for Pandas 
import plotly.graph_objs as go
# %matplotlib inline
cf.go_offline()
pyo.init_notebook_mode(connected=True)
import ipywidgets as widgets
import itertools
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
file_lenght=-len(os.path.abspath(".").split("\\")[-1])
csv_path =  os.path.abspath(".")[:file_lenght]+"Data\\"

types={       
    "PARTNERCATEGORY_CODE" : "category" 
    ,"PARTNERCATEGORYTYPE_CODE" : "category" 
    ,"VENDOR" : "category"           
    ,"SECTOR CODE" : "category"         
    ,"SECTOR NAME" : "category"       
    ,"REGION CODE" : "category"        
    ,"REGION NAME" : "category"       
    ,"PRODUCT_CODE" : "category"      
    ,"PRODUCT_NAME" : "category"       
    ,"PRODUCTPAGE_CODE" : "category"    
    ,"UNITPRICE" : "float16"
    ,"SOLD QUANTITY" : "float16"  
    ,"TURNOVER" : "float64"
    ,"DISCOUNT" : "float32" 
    ,"HOLIDAY" : "category"    
    ,"SCOLAR_HOLIDAY" : "category"     
    ,"ISLAM_EVENT" : "string"    
    ,"TEMPERATURE" : "float16"
    ,"HUMIDITY" : "float16"
} # reduce memory consumption
miniData = pd.read_csv(csv_path+"Boufarik_Dataset_v2.csv",header=0,engine='c',index_col=[0],dtype=types)
miniData=miniData.reset_index(drop=True)
miniData.head(1)
# Out:
#         ITINERARY_NAME PARTNER_CODE PARTNERCATEGORY_CODE  \
# 0  Sam/Mar, Boufarik 1     09/00016                    M
#
#   PARTNERCATEGORYTYPE_CODE VENDOR SECTOR CODE      SECTOR NAME REGION CODE  \
# 0                        M  0903R        1605  MD CHERIF SAMIR          16
#
#   REGION NAME PRODUCT_CODE  ... ISLAM_EVENT TEMPERATURE  HUMIDITY  DAYWEEK  \
# 0       ALGER    PF-000009  ...        <NA>    47.84375  0.830078        5
#
#    LONGETUDE  LATITUDE AMAZIGH_EVENT     MONTH  YEAR LOYALTY
# 0    36.7538    3.0588          NoEv  Janauary  2016       0
#
# [1 rows x 29 columns]

# %%
month ={'01':'Janauary',
        '02':'February',
        '03':'March',
        '04':'April',
        '05':'May',
        '06':'June',
        '07':'July',
        '08':'August',
        '09':'September',
        '10':'October',
        '11':'November',
        '12':'December'}
flipped_month = dict(zip(month.values(), month.keys()))

def f_year(date):
    return date[:4]
def f_month(date):
    return month[date[5:7]]
vect_month = np.vectorize(f_month)
vect_year = np.vectorize(f_year)

month_col = vect_month(miniData["GREGORIAN_DATE"])
month_cat = pd.CategoricalDtype(categories=flipped_month,ordered=True)

year_col = vect_year(miniData["GREGORIAN_DATE"])
year_cat = pd.CategoricalDtype(categories=["2016","2017","2018"],ordered=True)

miniData["MONTH"]=pd.Series(month_col).astype(month_cat)
miniData["YEAR"]=pd.Series(year_col).astype(year_cat)

# %%
gammes = miniData["PRODUCTPAGE_CODE"].drop_duplicates().tolist()
data1= list()
data = []
for gamme in tqdm(gammes):
    produits = miniData[miniData["PRODUCTPAGE_CODE"].str.match(gamme)]["PRODUCT_NAME"].drop_duplicates().tolist()
    for prod in produits:
        data1.append(miniData[miniData["PRODUCT_NAME"].str.match(prod)].drop_duplicates(["MONTH","YEAR"])[["PRODUCTPAGE_CODE","PRODUCT_NAME","MONTH","YEAR"]].iloc[0,:])
    data.append(pd.concat(data1, axis=1).transpose().set_index(["PRODUCTPAGE_CODE","PRODUCT_NAME"]))
    data1=list()
pd.concat(data)
# Out:
# ...
#                                                MONTH  YEAR
# PRODUCTPAGE_CODE    PRODUCT_NAME
# laits aromatis̩s   CHOCO 20CL              Janauary  2016
#                     CHOCO 1L                Janauary  2016
#                     FRAISE 20CL            September  2016
#                     BANANE 125 ML            October  2016
#                     CHOCO 125 ML             October  2016
#                     FRAISE 125 ML           November  2016
#                     CANDY CARAMEL 125 ML   September  2017
# Laits Blancs        ENTIER                  Janauary  2016
#                     DE 1L                   Janauary  2016
#                     SILHOUETTE              Janauary  2016
#                     VIVA                    Janauary  2016
#                     DE 50CL                 Janauary  2016
#                     DE 1L SANS LACTOSE        August  2018
# Boissons            COCKTAIL 1L             Janauary  2016
# ...

# %% [markdown]
# ## Monthly behaviour in BOUFARIK

# %%
month_seas=miniData.groupby(["MONTH","PARTNERCATEGORY_CODE"]).sum().dropna()["TURNOVER"].reset_index()
classes = miniData["PARTNERCATEGORY_CODE"].drop_duplicates().tolist()
data = [month_seas[month_seas["PARTNERCATEGORY_CODE"].str.match(classe)].groupby("MONTH").sum() for classe in classes]

fig = go.Figure(data=[ go.Bar(name=classes[i], x=data[i].index, y=data[i]["TURNOVER"].tolist()) for i in range(len(classes)) ])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
# Out:
# <div>
#
#
#             <div id="2a12ea21-72eb-4ee9-8e44-4202bfed99ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2a12ea21-72eb-4ee9-8e44-4202bfed99ab")) {
#                     Plotly.newPlot(
#                         '2a12ea21-72eb-4ee9-8e44-4202bfed99ab',
# ...

# %%
monthyear_seas=miniData.groupby(["YEAR","MONTH","PRODUCTPAGE_CODE"]).sum().dropna()["TURNOVER"].reset_index()
gammes = miniData["PRODUCTPAGE_CODE"].drop_duplicates().tolist()
data = [
        monthyear_seas[monthyear_seas["PRODUCTPAGE_CODE"].str.match(gamme)].groupby(["MONTH","YEAR"]).sum().groupby("MONTH").mean() 
    for gamme in gammes ]

fig = go.Figure(data=[ go.Bar(name=gammes[i], x=data[i].index, y=data[i]["TURNOVER"].tolist()) for i in range(len(gammes)) ])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
# Out:
# <div>
#
#
#             <div id="36c7dca0-dd21-4fbe-8315-1460760e90fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("36c7dca0-dd21-4fbe-8315-1460760e90fa")) {
#                     Plotly.newPlot(
#                         '36c7dca0-dd21-4fbe-8315-1460760e90fa',
# ...

# %%
monthyear_seas=miniData[miniData["PRODUCTPAGE_CODE"].str.match("Laits Blancs")].groupby(["YEAR","MONTH","PRODUCT_NAME"]).sum().dropna()["TURNOVER"].reset_index()
gammes = miniData[miniData["PRODUCTPAGE_CODE"].str.match("Laits Blancs")]["PRODUCT_NAME"].drop_duplicates().tolist()
data = [
        monthyear_seas[monthyear_seas["PRODUCT_NAME"].str.match(gamme)].groupby(["MONTH","YEAR"]).sum().groupby("MONTH").mean() 
    for gamme in gammes ]

fig = go.Figure(data=[ go.Bar(name=gammes[i], x=data[i].index, y=data[i]["TURNOVER"].tolist()) for i in range(len(gammes)) ])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
# Out:
# <div>
#
#
#             <div id="d82c42f1-33f1-421e-a7ad-f4e61baf6ff3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d82c42f1-33f1-421e-a7ad-f4e61baf6ff3")) {
#                     Plotly.newPlot(
#                         'd82c42f1-33f1-421e-a7ad-f4e61baf6ff3',
# ...

# %%
monthyear_seas=miniData[miniData["PRODUCTPAGE_CODE"].str.contains("laits aro")].groupby(["YEAR","MONTH","PRODUCT_NAME"]).sum().dropna()["TURNOVER"].reset_index()
gammes = miniData[miniData["PRODUCTPAGE_CODE"].str.contains("laits aro")]["PRODUCT_NAME"].drop_duplicates().tolist()
data = [
        monthyear_seas[monthyear_seas["PRODUCT_NAME"].str.match(gamme)].groupby(["MONTH","YEAR"]).sum().groupby("MONTH").mean() 
    for gamme in gammes ]

fig = go.Figure(data=[ go.Bar(name=gammes[i], x=data[i].index, y=data[i]["TURNOVER"].tolist()) for i in range(len(gammes)) ])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
# Out:
# <div>
#
#
#             <div id="66c52470-c033-42af-aec0-8879b40d0705" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("66c52470-c033-42af-aec0-8879b40d0705")) {
#                     Plotly.newPlot(
#                         '66c52470-c033-42af-aec0-8879b40d0705',
# ...

# %% [markdown]
# ## Weekly behaviour in BOUFARIK

# %%
WeekDays= {0:'Monday',
            1:'Tuesday',
            2:'Wednesday',
            3:'Thursday',
            4:'Friday',
            5:'Saturday',
            6:'Sunday'}
flipped_week = dict(zip(WeekDays.values(), WeekDays.keys()))

def f_day(date):
    return WeekDays[date]

vect_day = np.vectorize(f_day)


day_col = vect_day(miniData["DAYWEEK"])
day_cat = pd.CategoricalDtype(categories=flipped_week,ordered=True)

miniData["DAYWEEK"]=pd.Series(day_col).astype(day_cat)

# %%
month_seas=miniData.groupby(["DAYWEEK","PARTNERCATEGORY_CODE"]).sum().dropna()["TURNOVER"].reset_index()
classes = miniData["PARTNERCATEGORY_CODE"].drop_duplicates().tolist()
data = [month_seas[month_seas["PARTNERCATEGORY_CODE"].str.match(classe)].groupby("DAYWEEK").mean() for classe in classes]

fig = go.Figure(data=[ go.Bar(name=classes[i], x=data[i].index, y=data[i]["TURNOVER"].tolist()) for i in range(len(classes)) ])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
# Out:
# <div>
#
#
#             <div id="4f9ce3aa-d996-4e87-9199-f958982eed19" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4f9ce3aa-d996-4e87-9199-f958982eed19")) {
#                     Plotly.newPlot(
#                         '4f9ce3aa-d996-4e87-9199-f958982eed19',
# ...

# %%
week_seas=miniData.groupby(["DAYWEEK","PRODUCTPAGE_CODE"]).sum().dropna()["TURNOVER"].reset_index()
gammes = miniData["PRODUCTPAGE_CODE"].drop_duplicates().tolist()
data = [
        week_seas[week_seas["PRODUCTPAGE_CODE"].str.match(gamme)].groupby("DAYWEEK").mean() 
    for gamme in gammes ]

fig = go.Figure(data=[ go.Bar(name=gammes[i], x=data[i].index, y=data[i]["TURNOVER"].tolist()) for i in range(len(gammes)) ])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
# Out:
# <div>
#
#
#             <div id="79de65e8-67bf-4a9d-9eb1-3e5e6e529ea1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("79de65e8-67bf-4a9d-9eb1-3e5e6e529ea1")) {
#                     Plotly.newPlot(
#                         '79de65e8-67bf-4a9d-9eb1-3e5e6e529ea1',
# ...

# %%
month_seas=miniData.groupby(["DAYWEEK","PARTNERCATEGORY_CODE"]).count().dropna()["TURNOVER"].reset_index()
classes = miniData["PARTNERCATEGORY_CODE"].drop_duplicates().tolist()
data = [month_seas[month_seas["PARTNERCATEGORY_CODE"].str.match(classe)].groupby("DAYWEEK").mean() for classe in classes]

fig = go.Figure(data=[ go.Bar(name=classes[i], x=data[i].index, y=data[i]["TURNOVER"].tolist()) for i in range(len(classes)) ])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
# Out:
# <div>
#
#
#             <div id="773ebbdd-3958-4275-8118-b9620e403bcd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("773ebbdd-3958-4275-8118-b9620e403bcd")) {
#                     Plotly.newPlot(
#                         '773ebbdd-3958-4275-8118-b9620e403bcd',
# ...

# %%
week_seas=miniData[miniData["PRODUCTPAGE_CODE"].str.contains("laits aro")].groupby(["DAYWEEK","PRODUCT_NAME"]).sum().dropna()["TURNOVER"].reset_index()
gammes = miniData[miniData["PRODUCTPAGE_CODE"].str.contains("laits aro")]["PRODUCT_NAME"].drop_duplicates().tolist()
data = [
        week_seas[week_seas["PRODUCT_NAME"].str.match(gamme)].groupby("DAYWEEK").mean() 
    for gamme in gammes ]

fig = go.Figure(data=[ go.Bar(name=gammes[i], x=data[i].index, y=data[i]["TURNOVER"].tolist()) for i in range(len(gammes)) ])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
# Out:
# <div>
#
#
#             <div id="bd3a004a-45c2-499c-a87d-c269c0af71f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bd3a004a-45c2-499c-a87d-c269c0af71f0")) {
#                     Plotly.newPlot(
#                         'bd3a004a-45c2-499c-a87d-c269c0af71f0',
# ...

# %%
week_seas=miniData[miniData["PRODUCTPAGE_CODE"].str.match("Laits Blancs")].groupby(["DAYWEEK","PRODUCT_NAME"]).sum().dropna()["TURNOVER"].reset_index()
gammes = miniData[miniData["PRODUCTPAGE_CODE"].str.match("Laits Blancs")]["PRODUCT_NAME"].drop_duplicates().tolist()
data = [
        week_seas[week_seas["PRODUCT_NAME"].str.match(gamme)].groupby("DAYWEEK").mean() 
    for gamme in gammes ]

fig = go.Figure(data=[ go.Bar(name=gammes[i], x=data[i].index, y=data[i]["TURNOVER"].tolist()) for i in range(len(gammes)) ])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
# Out:
# <div>
#
#
#             <div id="712f1ffa-194e-4feb-8c39-cd6466051bf8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("712f1ffa-194e-4feb-8c39-cd6466051bf8")) {
#                     Plotly.newPlot(
#                         '712f1ffa-194e-4feb-8c39-cd6466051bf8',
# ...

# %% [markdown]
# ## EVENTS & HOLIDAYS

# %%
data = []
gammes = miniData["PRODUCTPAGE_CODE"].drop_duplicates().tolist()

for gamme in tqdm(gammes):
    data.append(miniData[miniData["PRODUCT_NAME"].str.match(gamme)])

# %% [markdown]
# **Amazigh**

# %%
amazigh_ev = miniData["AMAZIGH_EVENT"].drop_duplicates().tolist()
rolling_data = []
for prod in tqdm(miniData["PRODUCT_NAME"].drop_duplicates()):
    rolling_data.append(miniData[miniData["PRODUCT_NAME"].str.match(prod)].groupby(["PRODUCT_NAME","GREGORIAN_DATE","AMAZIGH_EVENT"]).sum().dropna().rolling(3).mean().reset_index())

# %%
Rolled_df = pd.concat(rolling_data)
Rolled_df
# Out:
#             PRODUCT_NAME GREGORIAN_DATE AMAZIGH_EVENT    UNITPRICE  \
# 0             CHOCO 20CL     2016-01-02          NoEv          NaN
# 1             CHOCO 20CL     2016-01-03          NoEv          NaN
# 2             CHOCO 20CL     2016-01-04          NoEv   790.000000
# 3             CHOCO 20CL     2016-01-05          NoEv   810.000000
# 4             CHOCO 20CL     2016-01-09          NoEv   830.000000
# ..                   ...            ...           ...          ...
# 0              ETUI 500G     2018-12-26          NoEv          NaN
# 1              ETUI 500G     2018-12-29          NoEv          NaN
# 0   ICE CREAM - CHOCOLAT     2018-07-23          NoEv          NaN
# 1   ICE CREAM - CHOCOLAT     2018-07-24          NoEv          NaN
# 2   ICE CREAM - CHOCOLAT     2018-07-30          NoEv  1013.333333
#
#     SOLD QUANTITY  TURNOVER  DISCOUNT  TEMPERATURE   HUMIDITY    DAYWEEK  \
# 0             NaN       NaN       NaN          NaN        NaN        NaN
# ...

# %%
products = data[0].reset_index()["PRODUCT_NAME"].drop_duplicates().tolist()
HM_data= [[Rolled_df[(Rolled_df["AMAZIGH_EVENT"].str.match(y)) & (Rolled_df["PRODUCT_NAME"].str.match(x))].mean()["TURNOVER"] for x in products] for y in tqdm(amazigh_ev)]
fig = go.Figure(data=go.Heatmap(
                   z=HM_data,
                x=products,
                y=amazigh_ev
               ))
fig.update_xaxes(side="top")
fig.show()
# Out:
# ...
# <div>
#
#
#             <div id="cb83bbb1-b0c9-4b42-b5e2-a7f983f9f688" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cb83bbb1-b0c9-4b42-b5e2-a7f983f9f688")) {
#                     Plotly.newPlot(
#                         'cb83bbb1-b0c9-4b42-b5e2-a7f983f9f688',
# ...

# %%
products = data[1].reset_index()["PRODUCT_NAME"].drop_duplicates().tolist()
HM_data= [[Rolled_df[(Rolled_df["AMAZIGH_EVENT"].str.match(y)) & (Rolled_df["PRODUCT_NAME"].str.match(x))].mean()["TURNOVER"] for x in products] for y in tqdm(amazigh_ev)]
fig = go.Figure(data=go.Heatmap(
                   z=HM_data,
                x=products,
                y=amazigh_ev
               ))
fig.update_xaxes(side="top")
fig.show()
# Out:
# ...
# <div>
#
#
#             <div id="7315a543-e4d0-49e2-8d4a-10e988e895dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7315a543-e4d0-49e2-8d4a-10e988e895dd")) {
#                     Plotly.newPlot(
#                         '7315a543-e4d0-49e2-8d4a-10e988e895dd',
# ...

# %%
products = data[2].reset_index()["PRODUCT_NAME"].drop_duplicates().tolist()
HM_data= [[Rolled_df[(Rolled_df["AMAZIGH_EVENT"].str.match(y)) & (Rolled_df["PRODUCT_NAME"].str.match(x))].mean()["TURNOVER"] for x in products] for y in tqdm(amazigh_ev)]
fig = go.Figure(data=go.Heatmap(
                   z=HM_data,
                x=products,
                y=amazigh_ev
               ))
fig.update_xaxes(side="top")
fig.show()
# Out:
# ...
# <div>
#
#
#             <div id="629160ac-7930-46ba-bd32-ea276722ee0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("629160ac-7930-46ba-bd32-ea276722ee0a")) {
#                     Plotly.newPlot(
#                         '629160ac-7930-46ba-bd32-ea276722ee0a',
# ...

# %%
products = data[3].reset_index()["PRODUCT_NAME"].drop_duplicates().tolist()
HM_data= [[Rolled_df[(Rolled_df["AMAZIGH_EVENT"].str.match(y)) & (Rolled_df["PRODUCT_NAME"].str.match(x))].mean()["TURNOVER"] for x in products] for y in tqdm(amazigh_ev)]
fig = go.Figure(data=go.Heatmap(
                   z=HM_data,
                x=products,
                y=amazigh_ev
               ))
fig.update_xaxes(side="top")
fig.show()
# Out:
# ...
# <div>
#
#
#             <div id="a010e452-64c8-408b-9f38-2c378f4508be" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a010e452-64c8-408b-9f38-2c378f4508be")) {
#                     Plotly.newPlot(
#                         'a010e452-64c8-408b-9f38-2c378f4508be',
# ...

# %% [markdown]
# **Holidays**

# %%
holiday_ev = miniData["HOLIDAY"].drop_duplicates().tolist()
rolling_data = []
for prod in tqdm(miniData["PRODUCT_NAME"].drop_duplicates()):
    rolling_data.append(miniData[miniData["PRODUCT_NAME"].str.match(prod)].groupby(["PRODUCT_NAME","GREGORIAN_DATE","HOLIDAY"]).sum().dropna().rolling(3).mean().reset_index())

# %%
Rolled_df = pd.concat(rolling_data)
Rolled_df
# Out:
#             PRODUCT_NAME GREGORIAN_DATE     HOLIDAY    UNITPRICE  \
# 0             CHOCO 20CL     2016-01-02   nouvel an          NaN
# 1             CHOCO 20CL     2016-01-03     travail          NaN
# 2             CHOCO 20CL     2016-01-04     travail   790.000000
# 3             CHOCO 20CL     2016-01-05     travail   810.000000
# 4             CHOCO 20CL     2016-01-09  revolution   830.000000
# ..                   ...            ...         ...          ...
# 0              ETUI 500G     2018-12-26        NoEv          NaN
# 1              ETUI 500G     2018-12-29        NoEv          NaN
# 0   ICE CREAM - CHOCOLAT     2018-07-23        NoEv          NaN
# 1   ICE CREAM - CHOCOLAT     2018-07-24        NoEv          NaN
# 2   ICE CREAM - CHOCOLAT     2018-07-30        NoEv  1013.333333
#
#     SOLD QUANTITY  TURNOVER  DISCOUNT  TEMPERATURE   HUMIDITY    DAYWEEK  \
# 0             NaN       NaN       NaN          NaN        NaN        NaN
# ...

# %%
products = data[0].reset_index()["PRODUCT_NAME"].drop_duplicates().tolist()
HM_data= [[Rolled_df[(Rolled_df["HOLIDAY"].str.match(y)) & (Rolled_df["PRODUCT_NAME"].str.match(x))].mean()["TURNOVER"] for x in products] for y in tqdm(holiday_ev)]
fig = go.Figure(data=go.Heatmap(
                   z=HM_data,
                x=products,
                y=holiday_ev
               ))
fig.update_xaxes(side="top")
fig.show()
# Out:
# ...
# <div>
#
#
#             <div id="6d4cd01f-625a-4b88-a74a-c8a6367de73f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6d4cd01f-625a-4b88-a74a-c8a6367de73f")) {
#                     Plotly.newPlot(
#                         '6d4cd01f-625a-4b88-a74a-c8a6367de73f',
# ...

# %%
products = data[1].reset_index()["PRODUCT_NAME"].drop_duplicates().tolist()
HM_data= [[Rolled_df[(Rolled_df["HOLIDAY"].str.match(y)) & (Rolled_df["PRODUCT_NAME"].str.match(x))].mean()["TURNOVER"] for x in products] for y in tqdm(holiday_ev)]
fig = go.Figure(data=go.Heatmap(
                   z=HM_data,
                x=products,
                y=holiday_ev
               ))
fig.update_xaxes(side="top")
fig.show()
# Out:
# ...
# <div>
#
#
#             <div id="624b98e6-2893-48f1-867b-b500254205ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("624b98e6-2893-48f1-867b-b500254205ee")) {
#                     Plotly.newPlot(
#                         '624b98e6-2893-48f1-867b-b500254205ee',
# ...

# %%
products = data[2].reset_index()["PRODUCT_NAME"].drop_duplicates().tolist()
HM_data= [[Rolled_df[(Rolled_df["HOLIDAY"].str.match(y)) & (Rolled_df["PRODUCT_NAME"].str.match(x))].mean()["TURNOVER"] for x in products] for y in tqdm(holiday_ev)]
fig = go.Figure(data=go.Heatmap(
                   z=HM_data,
                x=products,
                y=holiday_ev
               ))
fig.update_xaxes(side="top")
fig.show()
# Out:
# ...
# <div>
#
#
#             <div id="926864d6-aa14-46b0-90d7-8ddff1f39d02" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("926864d6-aa14-46b0-90d7-8ddff1f39d02")) {
#                     Plotly.newPlot(
#                         '926864d6-aa14-46b0-90d7-8ddff1f39d02',
# ...

# %%
products = data[3].reset_index()["PRODUCT_NAME"].drop_duplicates().tolist()
HM_data= [[Rolled_df[(Rolled_df["HOLIDAY"].str.match(y)) & (Rolled_df["PRODUCT_NAME"].str.match(x))].mean()["TURNOVER"] for x in products] for y in tqdm(holiday_ev)]
fig = go.Figure(data=go.Heatmap(
                   z=HM_data,
                x=products,
                y=holiday_ev
               ))
fig.update_xaxes(side="top")
fig.show()
# Out:
# ...
# <div>
#
#
#             <div id="340c82e2-dafb-4f81-98a0-f38001c4ac24" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("340c82e2-dafb-4f81-98a0-f38001c4ac24")) {
#                     Plotly.newPlot(
#                         '340c82e2-dafb-4f81-98a0-f38001c4ac24',
# ...

# %% [markdown]
# **scholar holidays**

# %%
scholar_ev = miniData["SCOLAR_HOLIDAY"].drop_duplicates().tolist()
rolling_data = []
for prod in miniData["PRODUCT_NAME"].drop_duplicates():
    rolling_data.append(miniData[miniData["PRODUCT_NAME"].str.match(prod)].groupby(["PRODUCT_NAME","GREGORIAN_DATE","SCOLAR_HOLIDAY"]).sum().dropna().rolling(3).mean().reset_index())
Rolled_df = pd.concat(rolling_data)
Rolled_df
# Out:
#             PRODUCT_NAME GREGORIAN_DATE SCOLAR_HOLIDAY    UNITPRICE  \
# 0             CHOCO 20CL     2016-01-02              1          NaN
# 1             CHOCO 20CL     2016-01-03              1          NaN
# 2             CHOCO 20CL     2016-01-04              0   790.000000
# 3             CHOCO 20CL     2016-01-05              0   810.000000
# 4             CHOCO 20CL     2016-01-09              0   830.000000
# ..                   ...            ...            ...          ...
# 0              ETUI 500G     2018-12-26              1          NaN
# 1              ETUI 500G     2018-12-29              1          NaN
# 0   ICE CREAM - CHOCOLAT     2018-07-23              1          NaN
# 1   ICE CREAM - CHOCOLAT     2018-07-24              1          NaN
# 2   ICE CREAM - CHOCOLAT     2018-07-30              1  1013.333333
#
#     SOLD QUANTITY  TURNOVER  DISCOUNT  TEMPERATURE   HUMIDITY    DAYWEEK  \
# 0             NaN       NaN       NaN          NaN        NaN        NaN
# ...

# %%
products = data[0].reset_index()["PRODUCT_NAME"].drop_duplicates().tolist()
HM_data= [[Rolled_df[(Rolled_df["SCOLAR_HOLIDAY"].str.match(y)) & (Rolled_df["PRODUCT_NAME"].str.match(x))].mean()["TURNOVER"] for x in products] for y in scholar_ev]
fig = go.Figure(data=go.Heatmap(
                   z=HM_data,
                x=products,
                y=scholar_ev
               ))
fig.update_xaxes(side="top")
fig.show()
# Out:
# <div>
#
#
#             <div id="eaa504f6-d7cf-4bd8-a564-585c068aa5ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("eaa504f6-d7cf-4bd8-a564-585c068aa5ef")) {
#                     Plotly.newPlot(
#                         'eaa504f6-d7cf-4bd8-a564-585c068aa5ef',
#                         [{"type": "heatmap", "x": ["CHOCO 20CL", "CHOCO 1L", "FRAISE 20CL", "BANANE 125 ML", "CHOCO 125 ML", "FRAISE 125 ML", "CANDY CARAMEL 125 ML"], "y": ["1", "0"], "z": [[65484.609137055835, 34232.17877094972, 2702.4, 3042.4615384615386, 27293.478260869564, 3489.7297297297296, 2104.6153846153848], [73877.83657587548, 35318.67942583732, 4808.85, 3096.2162162162163, 35135.555555555555, 3643.0188679245284, 3884.516129032258]]}],
# ...

# %%
products = data[1].reset_index()["PRODUCT_NAME"].drop_duplicates().tolist()
HM_data= [[Rolled_df[(Rolled_df["SCOLAR_HOLIDAY"].str.match(y)) & (Rolled_df["PRODUCT_NAME"].str.match(x))].mean()["TURNOVER"] for x in products] for y in scholar_ev]
fig = go.Figure(data=go.Heatmap(
                   z=HM_data,
                x=products,
                y=scholar_ev
               ))
fig.update_xaxes(side="top")
fig.show()
# Out:
# <div>
#
#
#             <div id="49a78e35-1432-4e05-a1e6-907e740bd4b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("49a78e35-1432-4e05-a1e6-907e740bd4b0")) {
#                     Plotly.newPlot(
#                         '49a78e35-1432-4e05-a1e6-907e740bd4b0',
#                         [{"type": "heatmap", "x": ["ENTIER", "DE 1L", "SILHOUETTE", "VIVA", "DE 50CL", "DE 1L SANS LACTOSE"], "y": ["1", "0"], "z": [[13264.90322580645, 88806.85814369384, 8677.768421052631, 32489.31937172775, 3271.9736842105262, 8381.481450888889], [14014.89075630252, 87944.35234983086, 9347.116666666667, 34290.403225806454, 3586.5034965034965, 3490.74073]]}],
# ...

# %%
products = data[2].reset_index()["PRODUCT_NAME"].drop_duplicates().tolist()
HM_data= [[Rolled_df[(Rolled_df["SCOLAR_HOLIDAY"].str.match(y)) & (Rolled_df["PRODUCT_NAME"].str.match(x))].mean()["TURNOVER"] for x in products] for y in scholar_ev]
fig = go.Figure(data=go.Heatmap(
                   z=HM_data,
                x=products,
                y=scholar_ev
               ))
fig.update_xaxes(side="top")
fig.show()
# Out:
# <div>
#
#
#             <div id="1adba65d-76ea-4ada-998c-1bde20dc9f96" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1adba65d-76ea-4ada-998c-1bde20dc9f96")) {
#                     Plotly.newPlot(
#                         '1adba65d-76ea-4ada-998c-1bde20dc9f96',
#                         [{"type": "heatmap", "x": ["COCKTAIL 1L", "COCKTAIL 20CL", "ORANGE 1L", "ORANGE 20CL", "CITRONNADE", "NECTAR DE GRENADE"], "y": ["1", "0"], "z": [[6442.712328767123, 3316.5789473684213, 5675.670588235294, 3468.0794701986756, 2664.246753246753, 2314.285714285714], [7067.986754966887, 3955.8333333333335, 6304.2216066482, 3802.2662889518415, 2928.827763496144, 3027.1244635193134]]}],
# ...

# %%
products = data[3].reset_index()["PRODUCT_NAME"].drop_duplicates().tolist()
HM_data= [[Rolled_df[(Rolled_df["SCOLAR_HOLIDAY"].str.match(y)) & (Rolled_df["PRODUCT_NAME"].str.match(x))].mean()["TURNOVER"] for x in products] for y in scholar_ev]
fig = go.Figure(data=go.Heatmap(
                   z=HM_data,
                x=products,
                y=scholar_ev
               ))
fig.update_xaxes(side="top")
fig.show()
# Out:
# <div>
#
#
#             <div id="2fc7f384-651b-49e8-9eca-d67da5900dc1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2fc7f384-651b-49e8-9eca-d67da5900dc1")) {
#                     Plotly.newPlot(
#                         '2fc7f384-651b-49e8-9eca-d67da5900dc1',
# ...

# %% [markdown]
# **islam events**

# %%
miniData["ISLAM_EVENT"]=miniData["ISLAM_EVENT"].fillna("noEV")
islamic_ev = miniData["ISLAM_EVENT"].drop_duplicates().tolist()
rolling_data = []
for prod in miniData["PRODUCT_NAME"].drop_duplicates():
    rolling_data.append(miniData[miniData["PRODUCT_NAME"].str.match(prod)].groupby(["PRODUCT_NAME","GREGORIAN_DATE","ISLAM_EVENT"]).sum().dropna().rolling(3).mean().reset_index())

# %%
Rolled_df = pd.concat(rolling_data)
Rolled_df
# Out:
#             PRODUCT_NAME GREGORIAN_DATE ISLAM_EVENT    UNITPRICE  \
# 0             CHOCO 20CL     2016-01-02        noEV          NaN
# 1             CHOCO 20CL     2016-01-03        noEV          NaN
# 2             CHOCO 20CL     2016-01-04        noEV   790.000000
# 3             CHOCO 20CL     2016-01-05        noEV   810.000000
# 4             CHOCO 20CL     2016-01-09        noEV   830.000000
# ..                   ...            ...         ...          ...
# 0              ETUI 500G     2018-12-26        noEV          NaN
# 1              ETUI 500G     2018-12-29        noEV          NaN
# 0   ICE CREAM - CHOCOLAT     2018-07-23        noEV          NaN
# 1   ICE CREAM - CHOCOLAT     2018-07-24        noEV          NaN
# 2   ICE CREAM - CHOCOLAT     2018-07-30        noEV  1013.333333
#
#     SOLD QUANTITY  TURNOVER  DISCOUNT  TEMPERATURE   HUMIDITY    DAYWEEK  \
# 0             NaN       NaN       NaN          NaN        NaN        NaN
# ...

# %%
products = data[0].reset_index()["PRODUCT_NAME"].drop_duplicates().tolist()
HM_data= [[Rolled_df[(Rolled_df["ISLAM_EVENT"].str.match(y)) & (Rolled_df["PRODUCT_NAME"].str.match(x))].mean()["TURNOVER"] for x in products] for y in islamic_ev]
fig = go.Figure(data=go.Heatmap(
                   z=HM_data,
                x=products,
                y=islamic_ev
               ))
fig.update_xaxes(side="top")
fig.show()
# Out:
# <div>
#
#
#             <div id="51bf8f03-3f05-4ad7-9dc3-2147ef62f8aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("51bf8f03-3f05-4ad7-9dc3-2147ef62f8aa")) {
#                     Plotly.newPlot(
#                         '51bf8f03-3f05-4ad7-9dc3-2147ef62f8aa',
# ...

# %%
products = data[1].reset_index()["PRODUCT_NAME"].drop_duplicates().tolist()
HM_data= [[Rolled_df[(Rolled_df["ISLAM_EVENT"].str.match(y)) & (Rolled_df["PRODUCT_NAME"].str.match(x))].mean()["TURNOVER"] for x in products] for y in islamic_ev]
fig = go.Figure(data=go.Heatmap(
                   z=HM_data,
                x=products,
                y=islamic_ev
               ))
fig.update_xaxes(side="top")
fig.show()
# Out:
# <div>
#
#
#             <div id="695bc68f-e726-4519-bf6d-cfa9d40a7b69" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("695bc68f-e726-4519-bf6d-cfa9d40a7b69")) {
#                     Plotly.newPlot(
#                         '695bc68f-e726-4519-bf6d-cfa9d40a7b69',
# ...

# %%
products = data[2].reset_index()["PRODUCT_NAME"].drop_duplicates().tolist()
HM_data= [[Rolled_df[(Rolled_df["ISLAM_EVENT"].str.match(y)) & (Rolled_df["PRODUCT_NAME"].str.match(x))].mean()["TURNOVER"] for x in products] for y in islamic_ev]
fig = go.Figure(data=go.Heatmap(
                   z=HM_data,
                x=products,
                y=islamic_ev
               ))
fig.update_xaxes(side="top")
fig.show()
# Out:
# <div>
#
#
#             <div id="d63028b9-20c1-4c19-86f6-3137cd79ff48" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d63028b9-20c1-4c19-86f6-3137cd79ff48")) {
#                     Plotly.newPlot(
#                         'd63028b9-20c1-4c19-86f6-3137cd79ff48',
# ...

# %%
products = data[3].reset_index()["PRODUCT_NAME"].drop_duplicates().tolist()
HM_data= [[Rolled_df[(Rolled_df["ISLAM_EVENT"].str.match(y)) & (Rolled_df["PRODUCT_NAME"].str.match(x))].mean()["TURNOVER"] for x in products] for y in islamic_ev]
fig = go.Figure(data=go.Heatmap(
                   z=HM_data,
                x=products,
                y=islamic_ev
               ))
fig.update_xaxes(side="top")
fig.show()
# Out:
# <div>
#
#
#             <div id="e2d3539c-9eb2-4604-b624-4b0b469e2966" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e2d3539c-9eb2-4604-b624-4b0b469e2966")) {
#                     Plotly.newPlot(
#                         'e2d3539c-9eb2-4604-b624-4b0b469e2966',
# ...

# %%
products = data[4].reset_index()["PRODUCT_NAME"].drop_duplicates().tolist()
HM_data= [[Rolled_df[(Rolled_df["ISLAM_EVENT"].str.match(y)) & (Rolled_df["PRODUCT_NAME"].str.match(x))].mean()["TURNOVER"] for x in products] for y in islamic_ev]
fig = go.Figure(data=go.Heatmap(
                   z=HM_data,
                x=products,
                y=islamic_ev
               ))
fig.update_xaxes(side="top")
fig.show()
# Out:
# <div>
#
#
#             <div id="9e21e37b-a82b-4716-93ce-f1443a964a26" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9e21e37b-a82b-4716-93ce-f1443a964a26")) {
#                     Plotly.newPlot(
#                         '9e21e37b-a82b-4716-93ce-f1443a964a26',
#                         [{"type": "heatmap", "x": ["PREPARATION CULINAIRE"], "y": ["noEV", "Ramadan", "Eid-al-Fitr", "Day of Ashura / Muharram", "Waqf al Arafa - Hajj", "Eid-al-Adha", "Lailat al Miraj", "Milad un Nabi"], "z": [[3885.9953060473968], [4138.541715000004], [null], [null], [null], [null], [null], [null]]}],
# ...

# %% [markdown]
# ## Weather

# %%
data = []
gammes = miniData["PRODUCTPAGE_CODE"].drop_duplicates().tolist()

for gamme in tqdm(gammes):
    data.append(miniData[miniData["PRODUCTPAGE_CODE"].str.match(gamme)])

# %%
import plotly.express as px
i=0
print(gammes[i])
df = data[i].groupby(["TEMPERATURE","HUMIDITY","GREGORIAN_DATE"]).sum().groupby(["TEMPERATURE","HUMIDITY"]).mean().reset_index()
fig = px.density_heatmap(df, x="TEMPERATURE", y="HUMIDITY", z="TURNOVER", histfunc="avg",color_continuous_scale="Viridis")

fig.show()
# Out:
# laits aromatis̩s
# <div>
#
#
#             <div id="d68b45c3-31cb-4a03-b9e2-7710a8d3c9d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d68b45c3-31cb-4a03-b9e2-7710a8d3c9d0")) {
#                     Plotly.newPlot(
#                         'd68b45c3-31cb-4a03-b9e2-7710a8d3c9d0',
# ...

# %%
import plotly.express as px
i=1
print(gammes[i])
df = data[i].groupby(["TEMPERATURE","HUMIDITY","GREGORIAN_DATE"]).sum().groupby(["TEMPERATURE","HUMIDITY"]).mean().reset_index()
fig = px.density_heatmap(df, x="TEMPERATURE", y="HUMIDITY", z="TURNOVER", histfunc="avg",color_continuous_scale="Viridis")
fig.show()
# Out:
# Laits Blancs
# <div>
#
#
#             <div id="32242d30-3d96-48a9-81e5-b5a364de7eef" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("32242d30-3d96-48a9-81e5-b5a364de7eef")) {
#                     Plotly.newPlot(
#                         '32242d30-3d96-48a9-81e5-b5a364de7eef',
# ...

# %%
import plotly.express as px
i=2
print(gammes[i])
df = data[i].groupby(["TEMPERATURE","HUMIDITY","GREGORIAN_DATE"]).sum().groupby(["TEMPERATURE","HUMIDITY"]).mean().reset_index()
fig = px.density_heatmap(df, x="TEMPERATURE", y="HUMIDITY", z="TURNOVER", histfunc="avg",color_continuous_scale="Viridis")
fig.show()
# Out:
# Boissons
# <div>
#
#
#             <div id="77789297-90f3-4a36-8ddd-a3d579d9f932" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("77789297-90f3-4a36-8ddd-a3d579d9f932")) {
#                     Plotly.newPlot(
#                         '77789297-90f3-4a36-8ddd-a3d579d9f932',
# ...

# %%
import plotly.express as px
i=3
print(gammes[i])
df = data[i].groupby(["TEMPERATURE","HUMIDITY","GREGORIAN_DATE"]).sum().groupby(["TEMPERATURE","HUMIDITY"]).mean().reset_index()
fig = px.density_heatmap(df, x="TEMPERATURE", y="HUMIDITY", z="TURNOVER", histfunc="avg",color_continuous_scale="Viridis")
fig.show()
# Out:
# Laits & Jus
# <div>
#
#
#             <div id="d442533b-2580-4c46-99a4-6664fae380c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d442533b-2580-4c46-99a4-6664fae380c1")) {
#                     Plotly.newPlot(
#                         'd442533b-2580-4c46-99a4-6664fae380c1',
# ...

# %%
miniData[miniData["PRODUCTPAGE_CODE"].str.match(gammes[3])].iloc[0,15:]
# Out:
# DISCOUNT                  36
# GREGORIAN_DATE    2016-01-02
# HOLIDAY            nouvel an
# SCOLAR_HOLIDAY             1
# ISLAM_EVENT             noEV
# TEMPERATURE          47.8438
# HUMIDITY            0.830078
# DAYWEEK                    5
# LONGETUDE            36.7538
# LATITUDE              3.0588
# AMAZIGH_EVENT           NoEv
# MONTH               Janauary
# YEAR                    2016
# LOYALTY                    0
# Name: 14, dtype: object

# %%
miniData.sort_values(by=["GREGORIAN_DATE"],axis=0,inplace=True)
# Out:
# 80354    2016-01-03
# 80355    2016-01-03
# 80356    2016-01-03
# 80357    2016-01-03
# 80358    2016-01-03
#             ...
# 38207    2018-12-30
# 38208    2018-12-30
# 38196    2018-12-30
# 86412    2018-12-31
# 12876    2018-12-31
# Name: GREGORIAN_DATE, Length: 24265, dtype: object

# %%
data=[]
value=miniData[(miniData["ITINERARY_NAME"].str.contains("Sam/Mar"))].groupby("GREGORIAN_DATE").sum().reset_index()
data.append(go.Scatter(
        x = value.index,
        y = value["TURNOVER"],
        mode="lines",
        name=f"CA",))
                             ###           PLOTING       ###
layout = go.Layout(title=f"CA Boufarik Sam/Mar")
fig=go.Figure(data=data,layout=layout)
pyo.iplot(fig)
# Out:
# <div>
#
#
#             <div id="a75fbc1a-7801-44ad-9829-df2313c09539" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a75fbc1a-7801-44ad-9829-df2313c09539")) {
#                     Plotly.newPlot(
#                         'a75fbc1a-7801-44ad-9829-df2313c09539',
# ...

# %%
data=[]
for gamme in tqdm(gammes):
    value=miniData[(miniData["ITINERARY_NAME"].str.contains("Sam/Mar"))  & (miniData["PRODUCTPAGE_CODE"].str.match(gamme))].groupby("GREGORIAN_DATE").sum()
    data.append(go.Scatter(
        x = value.index,
        y = value["TURNOVER"],
        mode="lines",
        name=f"{gamme}",))
                             ###           PLOTING       ###
layout = go.Layout(title=f"CA Boufarik Sam/Mar")
fig=go.Figure(data=data,layout=layout)
pyo.iplot(fig)
# Out:
# ...
# <div>
#
#
#             <div id="06f6bf57-b319-4321-9c19-31510a8fd829" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("06f6bf57-b319-4321-9c19-31510a8fd829")) {
#                     Plotly.newPlot(
#                         '06f6bf57-b319-4321-9c19-31510a8fd829',
# ...
