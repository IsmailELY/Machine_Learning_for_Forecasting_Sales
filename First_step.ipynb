# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
file_lenght=len(os.path.abspath(".").split("\\")[-1])
csv_path =  os.path.abspath(".")[:-file_lenght]
# 16 is the length of repository's name
# dataset should be outside the repository

# %% [markdown]
# <h1>Seperate and Merge Data</h1>
# <ul>
#     <li>1st Section for separating</li>
#     <li>2nd Section for merging</li>
# </ul>

# %%
for year in [2016,2017,2018]:
    for m in range(1,13):
        if m==12:
            data = myData[(myData["GREGORIAN_DATE"]>=f'{year}-{m}') & (myData["GREGORIAN_DATE"]<f'{year+1}-1')]
        myData[(myData["GREGORIAN_DATE"]>=f'{year}-{m}') & (myData["GREGORIAN_DATE"]<"2016-09")]
        data.to_csv(f'Data{year}_{m}.csv')

# %%
frames = []
for year in [2016,2017,2018]:
    for m in range(1,13):
        frames.append(eval(f'read_csv(csv_path+"Data{year}_{m}.csv",header=0,index_col=[0],low_memory=False)'))
myData = pd.concat(frames)
myData.to_csv(csv_path+"Dataset_2.csv")

# %% [markdown]
# <h1>Read the csv File</h1>

# %%
myData = pd.read_csv(csv_path+"Dataset_2.csv" , header = 0, sep='\t', encoding = 'latin-1')
myData.head()
# Out:
#   ITINERARY_CODE          ITINERARY_NAME      PERIODACTIVEDAY PARTNER_CODE  \
# 0         S02001  Samedi, Centre ville 1  2017-11-25 00:00:00      02/0002
# 1         S02001  Samedi, Centre ville 1  2017-11-25 00:00:00      02/0004
# 2         S02001  Samedi, Centre ville 1  2017-11-25 00:00:00      02/0004
# 3         S02001  Samedi, Centre ville 1  2017-11-25 00:00:00      02/0005
# 4         S02001  Samedi, Centre ville 1  2017-11-25 00:00:00      02/0006
#
#   PARTNERCATEGORY_CODE PARTNERCATEGORYTYPE_CODE VENDOR  SECTOR CODE  \
# 0                    M                        M  R0201          201
# 1                   GM                       GM  R0201          201
# 2                   GM                       GM  R0201          201
# 3                    M                        M  R0201          201
# 4                    M                        M  R0201          201
#
#            SECTOR NAME  REGION CODE REGION NAME PRODUCT_CODE PRODUCT_NAME  \
# 0  EURL ADEMLAIT-CHLEF            2       CHLEF    PF-000005       ENTIER
# 1  EURL ADEMLAIT-CHLEF            2       CHLEF    PF-000001        DE 1L
# 2  EURL ADEMLAIT-CHLEF            2       CHLEF    PF-000004         VIVA
# 3  EURL ADEMLAIT-CHLEF            2       CHLEF    PF-000002      DE 50CL
# 4  EURL ADEMLAIT-CHLEF            2       CHLEF    PF-000002      DE 50CL
#
#   PRODUCTPAGE_CODE  UNITPRICE SOLD QUANTITY        TURNOVER DISCOUNT
# 0     Laits Blancs  88,000000        12,000  1056,000000000  ,000000
# 1     Laits Blancs  83,333333        36,000  2999,999988000  ,000000
# 2     Laits Blancs  88,000000        36,000  3168,000000000  ,000000
# 3     Laits Blancs  45,000000        12,000   540,000000000  ,000000
# 4     Laits Blancs  45,000000        24,000  1080,000000000  ,000000

# %% [markdown]
# <h1>View all columns</h1>

# %%
Columns = myData.columns
Columns
# Out:
# Index(['ITINERARY_CODE', 'ITINERARY_NAME', 'PERIODACTIVEDAY', 'PARTNER_CODE',
#        'PARTNERCATEGORY_CODE', 'PARTNERCATEGORYTYPE_CODE', 'VENDOR',
#        'SECTOR CODE', 'SECTOR NAME', 'REGION CODE', 'REGION NAME',
#        'PRODUCT_CODE', 'PRODUCT_NAME', 'PRODUCTPAGE_CODE', 'UNITPRICE',
#        'SOLD QUANTITY', 'TURNOVER', 'DISCOUNT'],
#       dtype='object')

# %% [markdown]
# <h1>Make the float format readable by python</h1>

# %%
myData[Columns[-4]]=myData[Columns[-4]].map(lambda x:x.replace(",","."))
myData[Columns[-3]]=myData[Columns[-3]].map(lambda x:x.replace(",","."))
myData[Columns[-2]]=myData[Columns[-2]].map(lambda x:x.replace(",","."))
myData[Columns[-1]]=myData[Columns[-1]].map(lambda x:x.replace(",","."))
myData.head()
# Out:
#   ITINERARY_CODE          ITINERARY_NAME      PERIODACTIVEDAY PARTNER_CODE  \
# 0         S02001  Samedi, Centre ville 1  2017-11-25 00:00:00      02/0002
# 1         S02001  Samedi, Centre ville 1  2017-11-25 00:00:00      02/0004
# 2         S02001  Samedi, Centre ville 1  2017-11-25 00:00:00      02/0004
# 3         S02001  Samedi, Centre ville 1  2017-11-25 00:00:00      02/0005
# 4         S02001  Samedi, Centre ville 1  2017-11-25 00:00:00      02/0006
#
#   PARTNERCATEGORY_CODE PARTNERCATEGORYTYPE_CODE VENDOR  SECTOR CODE  \
# 0                    M                        M  R0201          201
# 1                   GM                       GM  R0201          201
# 2                   GM                       GM  R0201          201
# 3                    M                        M  R0201          201
# 4                    M                        M  R0201          201
#
#            SECTOR NAME  REGION CODE REGION NAME PRODUCT_CODE PRODUCT_NAME  \
# 0  EURL ADEMLAIT-CHLEF            2       CHLEF    PF-000005       ENTIER
# 1  EURL ADEMLAIT-CHLEF            2       CHLEF    PF-000001        DE 1L
# 2  EURL ADEMLAIT-CHLEF            2       CHLEF    PF-000004         VIVA
# 3  EURL ADEMLAIT-CHLEF            2       CHLEF    PF-000002      DE 50CL
# 4  EURL ADEMLAIT-CHLEF            2       CHLEF    PF-000002      DE 50CL
#
#   PRODUCTPAGE_CODE  UNITPRICE SOLD QUANTITY        TURNOVER DISCOUNT
# 0     Laits Blancs  88.000000        12.000  1056.000000000  .000000
# 1     Laits Blancs  83.333333        36.000  2999.999988000  .000000
# 2     Laits Blancs  88.000000        36.000  3168.000000000  .000000
# 3     Laits Blancs  45.000000        12.000   540.000000000  .000000
# 4     Laits Blancs  45.000000        24.000  1080.000000000  .000000

# %%
myData.shape
# Out:
# (15692870, 18)

# %% [markdown]
# <h1>Add columns</h1>

# %%
import json

# %% [markdown]
# <h3>1- Hijri Column</h3>

# %% [markdown]
# <p>Test the hijri date api</p>

# %%
import urllib.request as url
url=url.urlopen("http://api.aladhan.com/v1/gToH?date=02-05-2016")
data = json.loads(url.read().decode())
data["data"]["hijri"]["date"]
# Out:
# '24-07-1437'

# %%
d=myData2["GREGORIAN_DATE"][0]
d = d.split("-")
d = d[2]+"-"+d[1]+"-"+d[0]
d
# Out:
# '25-11-2017'

# %% [markdown]
# <p>this technique is so limited the api gives us only access to a specify number of requests and we need millions (not a strategic plan)</p>
# <p>It turns out that we don't need the hijri date but only the events so i decided to create a csv containing all the events associated to the country and now it's time to add the related columns : <b>event, kids_holiday, holiday</b></p>

# %% [markdown]
# <h3>1- Holiday Column</h3>

# %%
import seaborn as sns

# %%
Dates = myData["PERIODACTIVEDAY"]
myData["GREGORIAN_DATE"] = myData["PERIODACTIVEDAY"].map(lambda x: x[:-9])
myData=myData.drop("PERIODACTIVEDAY",axis=1)
myData.head()
# Out:
#   ITINERARY_CODE          ITINERARY_NAME PARTNER_CODE PARTNERCATEGORY_CODE  \
# 0         S02001  Samedi, Centre ville 1      02/0002                    M
# 1         S02001  Samedi, Centre ville 1      02/0004                   GM
# 2         S02001  Samedi, Centre ville 1      02/0004                   GM
# 3         S02001  Samedi, Centre ville 1      02/0005                    M
# 4         S02001  Samedi, Centre ville 1      02/0006                    M
#
#   PARTNERCATEGORYTYPE_CODE VENDOR  SECTOR CODE          SECTOR NAME  \
# 0                        M  R0201          201  EURL ADEMLAIT-CHLEF
# 1                       GM  R0201          201  EURL ADEMLAIT-CHLEF
# 2                       GM  R0201          201  EURL ADEMLAIT-CHLEF
# 3                        M  R0201          201  EURL ADEMLAIT-CHLEF
# 4                        M  R0201          201  EURL ADEMLAIT-CHLEF
#
#    REGION CODE REGION NAME PRODUCT_CODE PRODUCT_NAME PRODUCTPAGE_CODE  \
# 0            2       CHLEF    PF-000005       ENTIER     Laits Blancs
# 1            2       CHLEF    PF-000001        DE 1L     Laits Blancs
# 2            2       CHLEF    PF-000004         VIVA     Laits Blancs
# 3            2       CHLEF    PF-000002      DE 50CL     Laits Blancs
# 4            2       CHLEF    PF-000002      DE 50CL     Laits Blancs
#
#    UNITPRICE SOLD QUANTITY        TURNOVER DISCOUNT GREGORIAN_DATE
# 0  88.000000        12.000  1056.000000000  .000000     2017-11-25
# 1  83.333333        36.000  2999.999988000  .000000     2017-11-25
# 2  88.000000        36.000  3168.000000000  .000000     2017-11-25
# 3  45.000000        12.000   540.000000000  .000000     2017-11-25
# 4  45.000000        24.000  1080.000000000  .000000     2017-11-25

# %%
alger_holi = pd.read_csv(csv_path+"Data\\algerian_holiday.csv",usecols=["GREGORIAN_DATE","FERIER"],header=0,encoding="latin-1")
hijri_events = pd.read_csv(csv_path+"Data\\hijri_holidays.csv",header=0,encoding="latin-1")
scolar_holi = pd.read_csv(csv_path+"Data\\scolar_holidays.csv",header=0,encoding="utf-16")
hijri_events.head()
# Out:
#   GREGORIAN_DATE               ISLAMIC_HOLIDAY
# 0     2016-05-05               Lailat al Miraj
# 1     2016-05-22             Lailat al Bara'ah
# 2     2016-06-06               Ramadan (start)
# 3     2016-07-02                Laylat al Qadr
# 4     2016-07-06  Eid-al-Fitr (End of Ramadan)

# %% [markdown]
# #### Everyone's holiday

# %%
def data_format(date):
    date = date.split("/")
    return f'{date[2]}-{int(date[1]):02d}-{int(date[0]):02d}'
alger_holi["GREGORIAN_DATE"]=alger_holi["GREGORIAN_DATE"].map(lambda x: data_format(x))
alger_holi.head(1), hijri_events.head(1)
# Out:
# (  GREGORIAN_DATE     FERIER
#  0     2016-01-01  nouvel an,
#    GREGORIAN_DATE  ISLAMIC_HOLIDAY
#  0     2016-05-05  Lailat al Miraj)

# %%
myData2["HOLIDAY"]=0
myData2.loc[(myData2["GREGORIAN_DATE"].isin(alger_holi["GREGORIAN_DATE"].tolist())),"HOLIDAY"]=1
sns.heatmap(myData2["HOLIDAY"].to_frame(),cbar=False)

# %% [markdown]
# #### Children's holidays

# %%
myData2["SCOLAR_HOLIDAY"]=0
myData2.loc[(myData2["GREGORIAN_DATE"].isin(scolar_holi["GREGORIAN_DATE"].tolist())),"SCOLAR_HOLIDAY"]=1
sns.heatmap(myData2["SCOLAR_HOLIDAY"].to_frame(),cbar=False)

# %% [markdown]
# #### Hijri events (Muslims)

# %%
Dates = myData2["GREGORIAN_DATE"]
Events = myData2["GREGORIAN_DATE"].isin(hijri_events["GREGORIAN_DATE"].tolist())

def hijri_holiday(index):
    if Events[index]:
        try:
            return hijri_events[hijri_events["GREGORIAN_DATE"].str.match(Dates[index])]["ISLAMIC_HOLIDAY"][0]
        except KeyError as e:
            return hijri_events[hijri_events["GREGORIAN_DATE"].str.match(Dates[index])]["ISLAMIC_HOLIDAY"]                  
    else:
        return "None"
    
Hijri = myData2.reset_index()["index"].map(lambda x: hijri_holiday(x))
Hijri
# Out:
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
#             ...
# 15692865    None
# 15692866    None
# 15692867    None
# 15692868    None
# 15692869    None
# Name: index, Length: 15692870, dtype: object

# %%
myData2["ISLAM_EVENT"]=Hijri

# %%
Hijri.drop_duplicates().tolist()

# %%
myData["HOLIDAY"] = algerH_serie
myData["SCOLAR_HOLIDAY"] = scolarH_serie
myData["ISLAM_EVENT"] = hijri_serie
myData.head()
# Out:
#   ITINERARY_CODE          ITINERARY_NAME PARTNER_CODE PARTNERCATEGORY_CODE  \
# 0         S02001  Samedi, Centre ville 1      02/0002                    M
# 1         S02001  Samedi, Centre ville 1      02/0004                   GM
# 2         S02001  Samedi, Centre ville 1      02/0004                   GM
# 3         S02001  Samedi, Centre ville 1      02/0005                    M
# 4         S02001  Samedi, Centre ville 1      02/0006                    M
#
#   PARTNERCATEGORYTYPE_CODE VENDOR  SECTOR CODE          SECTOR NAME  \
# 0                        M  R0201          201  EURL ADEMLAIT-CHLEF
# 1                       GM  R0201          201  EURL ADEMLAIT-CHLEF
# 2                       GM  R0201          201  EURL ADEMLAIT-CHLEF
# 3                        M  R0201          201  EURL ADEMLAIT-CHLEF
# 4                        M  R0201          201  EURL ADEMLAIT-CHLEF
#
#    REGION CODE REGION NAME  ... PRODUCT_NAME PRODUCTPAGE_CODE  UNITPRICE  \
# 0            2       CHLEF  ...       ENTIER     Laits Blancs  88.000000
# 1            2       CHLEF  ...        DE 1L     Laits Blancs  83.333333
# 2            2       CHLEF  ...         VIVA     Laits Blancs  88.000000
# 3            2       CHLEF  ...      DE 50CL     Laits Blancs  45.000000
# 4            2       CHLEF  ...      DE 50CL     Laits Blancs  45.000000
#
#   SOLD QUANTITY        TURNOVER DISCOUNT GREGORIAN_DATE HOLIDAY  \
# 0        12.000  1056.000000000  .000000     2017-11-25       0
# 1        36.000  2999.999988000  .000000     2017-11-25       0
# 2        36.000  3168.000000000  .000000     2017-11-25       0
# 3        12.000   540.000000000  .000000     2017-11-25       0
# 4        24.000  1080.000000000  .000000     2017-11-25       0
#
#    SCOLAR_HOLIDAY  ISLAM_EVENT
# 0               0         None
# 1               0         None
# 2               0         None
# 3               0         None
# 4               0         None
#
# [5 rows x 21 columns]

# %%
Hijri.drop_duplicates().tolist()

# %% [markdown]
# <h4>CheckPoint</h4>
#     <i>Check that myData DataFrame has her event columns added before going any further</i>

# %%
#Path to Checkpoint file
csv_path =  os.path.abspath(".")[:-file_lenght]+"Data\\"

# %%
myData.to_csv(csv_path+"Updated_Data_1.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-103-c3f6c4279fc5> in <module>
# ----> 1 myData.to_csv(csv_path+"Updated_Data_1.csv")
#
# E:\user\anaconda\envs\Forecasting_sales\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# E:\user\anaconda\envs\Forecasting_sales\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# E:\user\anaconda\envs\Forecasting_sales\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\DatasetTab\\Machine_Learning_for_FData\\Updated_Data_1.csv'

# %%
ISLAM_EVENT#execute the checkpoint file path first
myData = pd.read_csv(csv_file,header=0,index_col=0)
myData.head()
# Out:
# E:\user\anaconda\envs\Forecasting_sales\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#   ITINERARY_CODE          ITINERARY_NAME PARTNER_CODE PARTNERCATEGORY_CODE  \
# 0         S02001  Samedi, Centre ville 1      02/0002                    M
# 1         S02001  Samedi, Centre ville 1      02/0004                   GM
# 2         S02001  Samedi, Centre ville 1      02/0004                   GM
# 3         S02001  Samedi, Centre ville 1      02/0005                    M
# 4         S02001  Samedi, Centre ville 1      02/0006                    M
#
#   PARTNERCATEGORYTYPE_CODE VENDOR  SECTOR CODE          SECTOR NAME  \
# 0                        M  R0201          201  EURL ADEMLAIT-CHLEF
# 1                       GM  R0201          201  EURL ADEMLAIT-CHLEF
# 2                       GM  R0201          201  EURL ADEMLAIT-CHLEF
# 3                        M  R0201          201  EURL ADEMLAIT-CHLEF
# 4                        M  R0201          201  EURL ADEMLAIT-CHLEF
#
#    REGION CODE REGION NAME  ... PRODUCT_NAME PRODUCTPAGE_CODE  UNITPRICE  \
# 0            2       CHLEF  ...       ENTIER     Laits Blancs  88.000000
# 1            2       CHLEF  ...        DE 1L     Laits Blancs  83.333333
# 2            2       CHLEF  ...         VIVA     Laits Blancs  88.000000
# 3            2       CHLEF  ...      DE 50CL     Laits Blancs  45.000000
# 4            2       CHLEF  ...      DE 50CL     Laits Blancs  45.000000
#
#    SOLD QUANTITY     TURNOVER  DISCOUNT  GREGORIAN_DATE HOLIDAY  \
# 0           12.0  1056.000000       0.0      2017-11-25       0
# 1           36.0  2999.999988       0.0      2017-11-25       0
# 2           36.0  3168.000000       0.0      2017-11-25       0
# 3           12.0   540.000000       0.0      2017-11-25       0
# 4           24.0  1080.000000       0.0      2017-11-25       0
#
#    SCOLAR_HOLIDAY  ISLAM_EVENT
# 0               0         None
# 1               0         None
# 2               0         None
# 3               0         None
# 4               0         None
#
# [5 rows x 21 columns]

# %% [markdown]
# <h3>2 - Humidity and temperature </h3>
# <p>Here we're going to try adding more columns related to weather</p>

# %% [markdown]
# <p><b>Part one : </b> Isolate the date & regions column to minimize the work
# <br><b>Part two : </b> Using API keys that we got from the <a href=https://darksky.net/>Darksky Api </a>. They gives 1000 request once you are registred. Hope you got sufficient accounts to accomplish your task</p>

# %%
def epoch_converter(date):
    return dtm.datetime(int(date.split("-")[0]),int(date.split("-")[1]),int(date.split("-")[2]),0,0).timestamp()
def long_lat_region(region):
    value = reg.index(region)
    return long[value],lat[value]

# %%
Region = myData[["REGION NAME","GREGORIAN_DATE"]].drop_duplicates()
Region["Epoch_time"] = Region["GREGORIAN_DATE"].map(lambda x: epoch_converter(x))
Region["Longetude"] = myData["REGION NAME"].map(lambda x:long_lat_region(x)[0])
Region["Latitude"] = myData["REGION NAME"].map(lambda x:long_lat_region(x)[1])
# Out:
#          REGION NAME GREGORIAN_DATE    Epoch_time  Longetude  Latitude
# 2751687       BOUIRA     2018-11-25  1.543100e+09    36.3692    3.9006
# 2751730       BOUIRA     2018-11-27  1.543273e+09    36.3692    3.9006
# 2751752       BOUIRA     2018-11-28  1.543360e+09    36.3692    3.9006
# 2751753       BOUIRA     2018-12-02  1.543705e+09    36.3692    3.9006
# 2751980       BOUIRA     2018-12-09  1.544310e+09    36.3692    3.9006
# ...              ...            ...           ...        ...       ...
# 12694934    RELIZANE     2018-08-01  1.533078e+09    35.7450    0.5579
# 12699803    RELIZANE     2018-07-07  1.530918e+09    35.7450    0.5579
# 12699968    RELIZANE     2018-07-28  1.532732e+09    35.7450    0.5579
# 12737200    RELIZANE     2016-09-29  1.475104e+09    35.7450    0.5579
# 13936424      DJELFA     2018-08-30  1.535584e+09    34.6704    3.2504
#
# [15489 rows x 5 columns]

# %%
import datetime as dtm
import requests as rq

#once all our regions are saved we got to find their coordinate and put them in the coord.csv file
details = pd.read_csv(csv_path+"coord.csv",header=0)
reg = details["REGION"].tolist()
long = details["LONGETUDE"].tolist()
lat = details["LATITUDE"].tolist()
API_Keys = ["48aa4110997c8qa753e57dbdf9e4c63g",] #put all your keys in this list like in the example

def get_temperature(long,lat,time):
    response = None
    while response is None:
        key=API_Keys[0]
        print("https://api.darksky.net/forecast/"+key+"/"+str(long)+","+str(lat)+","+str(int(time)))
        resp = rq.get("https://api.darksky.net/forecast/"+key+"/"+str(long)+","+str(lat)+","+str(int(time)))
        response = resp.json()
        try: 
            response = response["currently"]
        except KeyError as e:
            response=None
            API_Keys.pop(0)
    temp = None
    hum = None
    try :
        temp=response["temperature"]
    except KeyError as e:
        pass
    try :
        hum = response["humidity"]
    except KeyError as e:
        pass
    return temp,hum

# %%
Region.to_csv(path_csv+"Alger_Region_Upgraded.csv",index=False)

# %%
RegionR = pd.read_csv(path_csv+"Alger_Region_Upgraded.csv",header = 0)

# %% [markdown]
# <h3>this section should be iterated once</h3>

# %%
#this for loop can be executed as much as error as you get (example: not enough keys) 
#to be sure we keep track of the last iteration to continue the operation
#don't execute it more than once
last_index=0
save_index=0
# Out:
# 'Weather_API_result0.csv'

# %% [markdown]
# <h3>Remember to execute the next section too to save progress -- crucial error -- </h3>

# %%
API_Dict = {"temperature":[],"humidity":[]}
save_index+=1 
for i in range(last_index,RegionR.index.max()+1):
    last_index=i
    epoch=RegionR["Epoch_time"][i]
    long =RegionR["Longetude"][i]
    lat  =RegionR["Latitude"][i]
    resp =get_temperature(long,lat,epoch)
    API_Dict["temperature"].append(resp[0])
    API_Dict["humidity"].append(resp[1])
# Out:
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1536966000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1537225200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1537570800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1537830000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1538175600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1538434800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1538780400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1539039600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1539385200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1539644400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1539990000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1540249200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1540594800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1540854000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1541199600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1541458800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1541545200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1541804400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1542063600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1542409200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1542668400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1543014000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1543273200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1543618800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1543878000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1544223600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1544482800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1544828400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1545087600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1545433200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1545692400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1546038000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1535842800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1535929200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1536102000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1536447600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1536706800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1537052400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1537311600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1537657200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1537916400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1538262000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1538521200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1538866800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1539126000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1539471600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1539730800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1540076400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1540335600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1540681200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1540940400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1541286000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1541890800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1542150000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1542495600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1542754800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1543100400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1543359600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1543705200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1543964400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1544310000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1544569200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1544914800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1545174000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1545519600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1545778800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1546124400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1536188400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1536534000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1536793200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1537138800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1537398000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1537743600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1538002800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1538348400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1538607600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1538953200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1539212400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1539558000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1539817200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1540162800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1540422000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1540767600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1541026800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1541372400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1541631600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1541977200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1542236400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1542582000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1542841200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1543186800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1543446000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1543791600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1544050800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1544396400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1544655600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1545001200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1545260400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1545606000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1545865200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1546210800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/30.5833,2.8837,1542322800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1474066800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1474671600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1474930800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1475017200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1475276400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1475881200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1476486000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1477090800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1477695600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1478300400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1478386800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1478905200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1478991600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1479510000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1479682800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1480114800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1480287600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1480374000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1480719600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1480892400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1481324400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1481497200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1481929200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1482015600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1482188400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1482534000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1482706800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1483138800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1483225200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1483398000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1483484400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1483743600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1483916400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1484089200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1484348400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1484434800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1484521200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1484953200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1485039600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1485212400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1485298800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1485558000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1485644400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1485903600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1486162800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1486335600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1486422000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1486767600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1486940400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1487026800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1487113200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1487372400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1487545200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1487977200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1488150000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1488322800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1488582000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1488668400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1488754800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1489186800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1489532400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1489791600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1490050800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1490396400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1490569200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1490655600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1490742000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1491001200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1491174000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1491260400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1491606000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1491692400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1492210800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1492297200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1492560000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1492819200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1493078400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1493424000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1493510400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1493683200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1494028800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1494288000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1494374400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1494633600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1494806400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1494979200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1495238400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1495324800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1495584000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1495843200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1496444400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1497049200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1497135600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1497394800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1497654000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1497999600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1498086000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1498690800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1498863600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1499122800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1499209200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1499468400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1499554800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1499814000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1500073200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1500159600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1500246000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1500332400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1500418800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1500678000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1500850800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1501282800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1501542000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1501887600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1502146800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1502492400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1502578800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1502665200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1502838000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1503097200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1503442800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1503702000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1504393200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1504479600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1504911600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1505084400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1505257200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1505516400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1505602800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1506121200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1506207600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1506726000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1507330800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1507935600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1508540400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1508886000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1509145200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1509231600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1509490800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1509750000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1510095600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1510354800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1510959600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1511564400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1511650800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1511737200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1511823600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1512169200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1512255600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1512774000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1513119600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1513378800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1513465200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1513551600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1513983600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1514242800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1514588400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1514674800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1514761200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1515193200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1515279600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1515798000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1515884400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1516057200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1516402800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1516662000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1516748400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1517007600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1517094000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1517353200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1517612400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1517698800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1517785200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1517871600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1518217200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1518303600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1518390000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1518562800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1518822000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1519167600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1519426800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1520031600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1520290800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1520377200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1520636400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1520722800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1520809200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1520982000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1521241200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1521846000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1522105200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1522450800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1522796400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1523055600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1523660400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1523923200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1524268800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1524355200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1524873600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1525046400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1525478400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1525564800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1525737600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1526083200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1526169600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1526428800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1526688000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1527292800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1527379200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1527548400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1527894000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1528326000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1528498800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1528671600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1528758000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1529190000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1529276400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1529449200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1529535600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1529708400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1529794800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1530054000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1530313200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1530399600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1530486000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1530572400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1531004400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1531177200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1531522800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1531609200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1531868400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1532127600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1532473200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1532818800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1532905200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1533337200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1533596400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1533682800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1533942000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1534114800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1534287600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1534374000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1534633200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1534719600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1535151600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1535324400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1544828400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1474153200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1474758000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1475362800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1475967600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1476572400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1477177200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1477782000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1479596400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1480201200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1480806000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1481410800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1482620400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1483830000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1486249200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1486854000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1487458800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1488063600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1489273200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1489878000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1490482800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1491087600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1492905600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1494115200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1494720000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1495929600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1496530800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1497740400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1498950000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1500764400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1501369200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1501974000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1503183600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1503788400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1504998000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1506812400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1507417200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1508022000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1508626800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1509836400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1510441200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1510614000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1511046000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1512860400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1514070000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1516489200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1518908400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1519513200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1520118000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1520204400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1521327600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1521932400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1522018800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1522537200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1523142000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1523746800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1524528000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1524960000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1526774400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1527980400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1532214000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1533423600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1534028400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1534546800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1535238000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1474239600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1474844400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1475449200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1476054000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1476658800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1477263600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1477868400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1478473200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1479078000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1482102000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1483311600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1485126000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1485730800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1489359600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1489964400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1491778800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1492387200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1492992000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1493596800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1494201600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1495411200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1496012400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1496617200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1497222000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1497826800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1498258800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1499036400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1499641200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1501455600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1502060400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1503270000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1503874800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1505689200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1506294000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1506898800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1507503600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1508108400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1508713200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1509318000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1509922800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1510527600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1511132400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1512342000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1512946800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1514156400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1515366000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1515452400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1515970800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1516575600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1517180400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1518994800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1519599600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1519686000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1520895600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1521414000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1521500400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1521586800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1522623600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1524441600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1525651200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1526256000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1526860800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1527033600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1527462000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1528066800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1528585200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1529362800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1529881200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1530658800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1531090800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1531263600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1531695600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1532300400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1533510000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1534201200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1474326000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1475535600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1476140400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1476745200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1477350000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1477954800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1478559600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1479164400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1479769200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1480978800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1481583600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1482793200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1484002800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1484607600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1485817200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1487631600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1488236400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1488841200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1489446000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1491865200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1492473600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1494892800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1495497600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1496098800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1496703600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1497308400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1497913200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1499727600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1500937200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1502751600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1503356400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1503961200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1504566000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1505170800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1505775600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1506380400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1506985200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1507590000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1508194800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1508799600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1509404400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1510009200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1511218800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1512428400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1513033200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1513638000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1514847600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1517266800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1517958000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1518476400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1519081200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1522710000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1524009600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1525132800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1526342400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1526947200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1528153200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1529967600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1531782000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1532386800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1532991600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1474412400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1475622000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1476226800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1476831600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1477436400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1478041200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1478646000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1479250800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1479855600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1480460400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1481065200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1481670000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1482274800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1482879600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1484694000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1486508400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1487718000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1488927600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1490137200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1491346800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1491951600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1493164800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1493769600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1496185200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1496790000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1501023600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1501628400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1502233200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1504047600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1504652400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1505862000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1506466800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1507071600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1507676400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1508281200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1510700400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1511305200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1511910000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1512514800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1513724400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1514329200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1514934000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1515538800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1516143600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1519772400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1522191600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1524614400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1525219200
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1525824000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1527634800
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1528239600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1533078000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1530918000
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1532732400
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/35.745,0.5579,1475103600
# https://api.darksky.net/forecast/48aa4110997c86a753f57dbdf9e4c63d/34.6704,3.2504,1535583600

# %%
result = pd.DataFrame(API_Dict)
result.to_csv(f'Weather_API_result{save_index}.csv')

# %% [markdown]
# <h3>Merge the results in a DataFrame and then add them to the primary Data File</h3>

# %%
frame = list()
for i in range(1,save_index+1):
    Weather = eval(f'pd.read_csv("Weather_API_result{save_index}.csv,header=0,index_col=0)")')
    frame.append(Weather)
Weather.head()
# Out:
#    temperature  humidity
# 0        55.59      0.54
# 1        53.78      0.81
# 2        53.78      0.76
# 3        57.38      0.71
# 4        48.39      0.93

# %%
weather_csv = pd.concat(frames)
weather_csv=weather_csv.drop("index",axis=1)
weather_csv=weather_csv.reset_index()
weather_csv.shape,RegionR.shape
# Out:
# ((20489, 3), (20489, 5))

# %% [markdown]
# <h3>Check the null Values</h3>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# %%
RegionR["temperature"]=weather_csv["temperature"]
RegionR["humidity"]=weather_csv["humidity"]
sns.heatmap(weather_csv.isnull(),cbar=False)

# %%
RegionR.head()
# Out:
#   REGION NAME GREGORIAN_DATE    Epoch_time  Longetude  Latitude  temperature  \
# 0       CHLEF     2017-11-25  1.511564e+09     36.158    1.3373        55.59
# 1       CHLEF     2017-11-27  1.511737e+09     36.158    1.3373        53.78
# 2       CHLEF     2017-11-28  1.511824e+09     36.158    1.3373        53.78
# 3       CHLEF     2017-11-29  1.511910e+09     36.158    1.3373        57.38
# 4       CHLEF     2017-12-02  1.512169e+09     36.158    1.3373        48.39
#
#    humidity
# 0      0.54
# 1      0.81
# 2      0.76
# 3      0.71
# 4      0.93

# %%
def temp_humid(region,date):
    RSet=RegionR[(RegionR["REGION NAME"]==region) & (RegionR["GREGORIAN_DATE"]==str(date))]
    try:
        temp=float(RSet["temperature"])
        humid=float(RSet["humidity"])
    except KeyError as e:
        temp=RSet["temperature"][0]
        humid=RSet["humidity"][0]
    return "{}-{}".format(temp,humid)

def temp_humid2(region,date):
    RSet=RegionR[(RegionR["REGION NAME"]==region) & (RegionR["GREGORIAN_DATE"]==str(date))]
    try:
        temp=float(RSet["temperature"])
        humid=float(RSet["humidity"])
    except KeyError as e:
        temp=RSet["temperature"][0]
        humid=RSet["humidity"][0]
    return temp,humid

temp_humid("CHLEF","2017-11-25").split("-"),temp_humid2("CHLEF","2017-11-25")
# Out:
# (['55.59', '0.54'], (55.59, 0.54))

# %%
DataSetR= myData["REGION NAME"].tolist()
DataSetD= myData["GREGORIAN_DATE"].tolist()

# %%
Weather_T=[] #working with arrays is much faster
Weather_H=[]
for i in tqdm(range(len(DataSetD))):
    val = temp_humid2(DataSetR[i],DataSetD[i])
    Weather_T.append(val[0])
    Weather_H.append(val[1])

# %%
len(Weather_T),myData.shape
# Out:
# (15692870, (15692870, 21))

# %%
myData["TEMPERATURE"] = pd.Series(Weather_T)
myData["HUMIDITY"] = pd.Series(Weather_H)
myData.head()
# Out:
#   ITINERARY_CODE          ITINERARY_NAME PARTNER_CODE PARTNERCATEGORY_CODE  \
# 0         S02001  Samedi, Centre ville 1      02/0002                    M
# 1         S02001  Samedi, Centre ville 1      02/0004                   GM
# 2         S02001  Samedi, Centre ville 1      02/0004                   GM
# 3         S02001  Samedi, Centre ville 1      02/0005                    M
# 4         S02001  Samedi, Centre ville 1      02/0006                    M
#
#   PARTNERCATEGORYTYPE_CODE VENDOR  SECTOR CODE          SECTOR NAME  \
# 0                        M  R0201          201  EURL ADEMLAIT-CHLEF
# 1                       GM  R0201          201  EURL ADEMLAIT-CHLEF
# 2                       GM  R0201          201  EURL ADEMLAIT-CHLEF
# 3                        M  R0201          201  EURL ADEMLAIT-CHLEF
# 4                        M  R0201          201  EURL ADEMLAIT-CHLEF
#
#    REGION CODE REGION NAME  ...  UNITPRICE SOLD QUANTITY     TURNOVER  \
# 0            2       CHLEF  ...  88.000000          12.0  1056.000000
# 1            2       CHLEF  ...  83.333333          36.0  2999.999988
# 2            2       CHLEF  ...  88.000000          36.0  3168.000000
# 3            2       CHLEF  ...  45.000000          12.0   540.000000
# 4            2       CHLEF  ...  45.000000          24.0  1080.000000
#
#    DISCOUNT  GREGORIAN_DATE  HOLIDAY  SCOLAR_HOLIDAY ISLAM_EVENT  TEMPERATURE  \
# 0       0.0      2017-11-25        0               0        None        55.59
# 1       0.0      2017-11-25        0               0        None        55.59
# 2       0.0      2017-11-25        0               0        None        55.59
# 3       0.0      2017-11-25        0               0        None        55.59
# 4       0.0      2017-11-25        0               0        None        55.59
#
#    HUMIDITY
# 0      0.54
# 1      0.54
# 2      0.54
# 3      0.54
# 4      0.54
#
# [5 rows x 23 columns]

# %% [markdown]
# <p><b>CheckPoint 2</b></p>

# %%
myData2.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 ITINERARY_CODE          ITINERARY_NAME  \
# 0           0             0         S02001  Samedi, Centre ville 1
# 1           1             1         S02001  Samedi, Centre ville 1
# 2           2             2         S02001  Samedi, Centre ville 1
# 3           3             3         S02001  Samedi, Centre ville 1
# 4           4             4         S02001  Samedi, Centre ville 1
#
#   PARTNER_CODE PARTNERCATEGORY_CODE PARTNERCATEGORYTYPE_CODE VENDOR  \
# 0      02/0002                    M                        M  R0201
# 1      02/0004                   GM                       GM  R0201
# 2      02/0004                   GM                       GM  R0201
# 3      02/0005                    M                        M  R0201
# 4      02/0006                    M                        M  R0201
#
#    SECTOR CODE          SECTOR NAME  ...  UNITPRICE SOLD QUANTITY  \
# 0          201  EURL ADEMLAIT-CHLEF  ...  88.000000          12.0
# 1          201  EURL ADEMLAIT-CHLEF  ...  83.333333          36.0
# 2          201  EURL ADEMLAIT-CHLEF  ...  88.000000          36.0
# 3          201  EURL ADEMLAIT-CHLEF  ...  45.000000          12.0
# 4          201  EURL ADEMLAIT-CHLEF  ...  45.000000          24.0
#
#       TURNOVER DISCOUNT GREGORIAN_DATE  HOLIDAY  SCOLAR_HOLIDAY  ISLAM_EVENT  \
# 0  1056.000000      0.0     2017-11-25        0               0         None
# 1  2999.999988      0.0     2017-11-25        0               0         None
# 2  3168.000000      0.0     2017-11-25        0               0         None
# 3   540.000000      0.0     2017-11-25        0               0         None
# 4  1080.000000      0.0     2017-11-25        0               0         None
#
#    TEMPERATURE HUMIDITY
# 0        55.59     0.54
# 1        55.59     0.54
# 2        55.59     0.54
# 3        55.59     0.54
# 4        55.59     0.54
#
# [5 rows x 25 columns]

# %%
myData2.to_csv(csv_path+"Data\\Updated_Data_2.csv")

# %%
myData2["ISLAM_EVENT"].drop_duplicates().tolist()

# %% [markdown]
# <h4>Heatmap of Null Values</h4>

# %%
myData2 = pd.read_csv(csv_path+"Data\\Updated_Data_2.csv" , header = 0, encoding = 'latin-1',low_memory=False)
# Out:
#    Unnamed: 0  Unnamed: 0.1 ITINERARY_CODE          ITINERARY_NAME  \
# 0           0             0         S02001  Samedi, Centre ville 1
# 1           1             1         S02001  Samedi, Centre ville 1
# 2           2             2         S02001  Samedi, Centre ville 1
# 3           3             3         S02001  Samedi, Centre ville 1
# 4           4             4         S02001  Samedi, Centre ville 1
#
#   PARTNER_CODE PARTNERCATEGORY_CODE PARTNERCATEGORYTYPE_CODE VENDOR  \
# 0      02/0002                    M                        M  R0201
# 1      02/0004                   GM                       GM  R0201
# 2      02/0004                   GM                       GM  R0201
# 3      02/0005                    M                        M  R0201
# 4      02/0006                    M                        M  R0201
#
#    SECTOR CODE          SECTOR NAME  ...  UNITPRICE SOLD QUANTITY  \
# 0          201  EURL ADEMLAIT-CHLEF  ...  88.000000          12.0
# 1          201  EURL ADEMLAIT-CHLEF  ...  83.333333          36.0
# 2          201  EURL ADEMLAIT-CHLEF  ...  88.000000          36.0
# 3          201  EURL ADEMLAIT-CHLEF  ...  45.000000          12.0
# 4          201  EURL ADEMLAIT-CHLEF  ...  45.000000          24.0
#
#       TURNOVER DISCOUNT GREGORIAN_DATE  HOLIDAY  SCOLAR_HOLIDAY  ISLAM_EVENT  \
# 0  1056.000000      0.0     2017-11-25        0               0         None
# 1  2999.999988      0.0     2017-11-25        0               0         None
# 2  3168.000000      0.0     2017-11-25        0               0         None
# 3   540.000000      0.0     2017-11-25        0               0         None
# 4  1080.000000      0.0     2017-11-25        0               0         None
#
#    TEMPERATURE HUMIDITY
# 0        55.59     0.54
# 1        55.59     0.54
# 2        55.59     0.54
# 3        55.59     0.54
# 4        55.59     0.54
#
# [5 rows x 25 columns]

# %%
myData2 = myData2["SCOLAR_HOLIDAY"]== 1
myData2.reset_index()
# Out:
#           ISLAM_EVENT
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ...               ...
# 15692865        False
# 15692866        False
# 15692867        False
# 15692868        False
# 15692869        False
#
# [15692870 rows x 1 columns]

# %%
sns.heatmap(myData2.to_frame(),cbar=False)
